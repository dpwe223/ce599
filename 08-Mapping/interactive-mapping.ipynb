# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1da2179d2e65471ca9b964880dee0104%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1da2179d2e65471ca9b964880dee0104%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1da2179d2e65471ca9b964880dee0104%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1da2179d2e65471ca9b964880dee0104%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_42fc55da63724f7a8dca96c5d9e1f27d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_42fc55da63724f7a8dca96c5d9e1f27d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_42fc55da63724f7a8dca96c5d9e1f27d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_42fc55da63724f7a8dca96c5d9e1f27d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
pd.set_option('display.max_columns', None)
print(airports)
# Out:
#          id                                         name          city  \
# 0         1                               Goroka Airport        Goroka
# 1         2                               Madang Airport        Madang
# 2         3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3         4                               Nadzab Airport        Nadzab
# 4         5  Port Moresby Jacksons International Airport  Port Moresby
# ...     ...                                          ...           ...
# 7179  12053                               Rugao Air Base         Rugao
# 7180  12054                                Wuhu Air Base          Wuhu
# 7181  12055                             Shanshan Airport      Shanshan
# 7182  12056                        Yingkou Lanqi Airport       Yingkou
# 7183  12057                      Shenyang Dongta Airport      Shenyang
#
#                country iata  icao   latitude   longitude  altitude  timezone  \
# 0     Papua New Guinea  GKA  AYGA  -6.081690  145.391998      5282      10.0
# 1     Papua New Guinea  MAG  AYMD  -5.207080  145.789001        20      10.0
# 2     Papua New Guinea  HGU  AYMH  -5.826790  144.296005      5388      10.0
# 3     Papua New Guinea  LAE  AYNZ  -6.569803  146.725977       239      10.0
# 4     Papua New Guinea  POM  AYPY  -9.443380  147.220001       146      10.0
# ...                ...  ...   ...        ...         ...       ...       ...
# 7179             China  RUG  ZSRG  32.257885  120.501656         0       NaN
# 7180             China  WHU  ZSWU  31.390600  118.408997         0       NaN
# 7181             China  SXJ  ZWSS  42.911701   90.247498         0       NaN
# 7182             China  YKH  ZYYK  40.542524  122.358600         0       NaN
# 7183             China  NaN  ZYYY  41.784401  123.496002         0       NaN
#
#       dst                    tz     type       source
# 0       U  Pacific/Port_Moresby  airport  OurAirports
# 1       U  Pacific/Port_Moresby  airport  OurAirports
# 2       U  Pacific/Port_Moresby  airport  OurAirports
# 3       U  Pacific/Port_Moresby  airport  OurAirports
# 4       U  Pacific/Port_Moresby  airport  OurAirports
# ...   ...                   ...      ...          ...
# 7179  NaN                   NaN  airport  OurAirports
# 7180  NaN                   NaN  airport  OurAirports
# 7181  NaN                   NaN  airport  OurAirports
# 7182  NaN                   NaN  airport  OurAirports
# 7183  NaN                   NaN  airport  OurAirports
#
# [7184 rows x 14 columns]

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
pd.set_option('display.max_columns', None)
print(routes)
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0          2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1          2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2          2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3          2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4          2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
# ...       ...         ...    ...        ...  ...      ...       ...    ...
# 67658      ZL      4178.0    WYA     6334.0  ADL   3341.0       NaN      0
# 67659      ZM     19016.0    DME     4029.0  FRU   2912.0       NaN      0
# 67660      ZM     19016.0    FRU     2912.0  DME   4029.0       NaN      0
# 67661      ZM     19016.0    FRU     2912.0  OSS   2913.0       NaN      0
# 67662      ZM     19016.0    OSS     2913.0  FRU   2912.0       NaN      0
#
#       equipment
# 0           CR2
# 1           CR2
# 2           CR2
# 3           CR2
# 4           CR2
# ...         ...
# 67658       SF3
# 67659       734
# 67660       734
# 67661       734
# 67662       734
#
# [67663 rows x 9 columns]

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)
# Out:
# 1435

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]], popup=row['name'])
        marker.add_to(airports_map)
        
# Save it to a file (it's kinda big for the notebook)
airports_map.save('airports.html')

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     popup=row['name'])
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes
# Out:
#    airline  airline_id source_x  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0      LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0      LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0      LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0      LEX     4017.0  ORD   3830.0         Y      0
# 4       AF       137.0      LEX     4017.0  ATL   3682.0         Y      0
# 5       DL      2009.0      LEX     4017.0  ATL   3682.0       NaN      0
# 6       DL      2009.0      LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0      LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0      LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0      LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0      LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0      LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0      LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0      LEX     4017.0  SFB   4167.0       NaN      0
# 14      KL      3090.0      LEX     4017.0  ATL   3682.0         Y      0
# 15      UA      5209.0      LEX     4017.0  IAH   3550.0         Y      0
# 16      UA      5209.0      LEX     4017.0  ORD   3830.0         Y      0
# 17      US      5265.0      LEX     4017.0  CLT   3876.0       NaN      0
# 18      US      5265.0      LEX     4017.0  DFW   3670.0       NaN      0
# 19      US      5265.0      LEX     4017.0  ORD   3830.0         Y      0
#
#       equipment  id_source         name_source   city_source country_source  \
# 0           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 1       CR7 CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 2       ERD ER4       4017  Blue Grass Airport  Lexington KY  United States
# 3       ERD ER4       4017  Blue Grass Airport  Lexington KY  United States
# 4       CRJ CR9       4017  Blue Grass Airport  Lexington KY  United States
# 5       M88 717       4017  Blue Grass Airport  Lexington KY  United States
# 6           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 7   CR7 CRJ CR9       4017  Blue Grass Airport  Lexington KY  United States
# 8           ERJ       4017  Blue Grass Airport  Lexington KY  United States
# 9           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 10          M80       4017  Blue Grass Airport  Lexington KY  United States
# 11          M80       4017  Blue Grass Airport  Lexington KY  United States
# 12          320       4017  Blue Grass Airport  Lexington KY  United States
# 13      M80 320       4017  Blue Grass Airport  Lexington KY  United States
# 14      CR9 CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 15          ERJ       4017  Blue Grass Airport  Lexington KY  United States
# 16      ERJ CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 17          CR7       4017  Blue Grass Airport  Lexington KY  United States
# 18          ERD       4017  Blue Grass Airport  Lexington KY  United States
# 19      ERD ER4       4017  Blue Grass Airport  Lexington KY  United States
#
#    iata_source icao_source  latitude_source  longitude_source  \
# 0          LEX        KLEX        38.036499        -84.605904
# 1          LEX        KLEX        38.036499        -84.605904
# 2          LEX        KLEX        38.036499        -84.605904
# 3          LEX        KLEX        38.036499        -84.605904
# 4          LEX        KLEX        38.036499        -84.605904
# 5          LEX        KLEX        38.036499        -84.605904
# 6          LEX        KLEX        38.036499        -84.605904
# 7          LEX        KLEX        38.036499        -84.605904
# 8          LEX        KLEX        38.036499        -84.605904
# 9          LEX        KLEX        38.036499        -84.605904
# 10         LEX        KLEX        38.036499        -84.605904
# 11         LEX        KLEX        38.036499        -84.605904
# 12         LEX        KLEX        38.036499        -84.605904
# 13         LEX        KLEX        38.036499        -84.605904
# 14         LEX        KLEX        38.036499        -84.605904
# 15         LEX        KLEX        38.036499        -84.605904
# 16         LEX        KLEX        38.036499        -84.605904
# 17         LEX        KLEX        38.036499        -84.605904
# 18         LEX        KLEX        38.036499        -84.605904
# 19         LEX        KLEX        38.036499        -84.605904
#
#     altitude_source  timezone_source dst_source         tz_source type_source  \
# 0               979             -5.0          A  America/New_York     airport
# 1               979             -5.0          A  America/New_York     airport
# 2               979             -5.0          A  America/New_York     airport
# 3               979             -5.0          A  America/New_York     airport
# 4               979             -5.0          A  America/New_York     airport
# 5               979             -5.0          A  America/New_York     airport
# 6               979             -5.0          A  America/New_York     airport
# 7               979             -5.0          A  America/New_York     airport
# 8               979             -5.0          A  America/New_York     airport
# 9               979             -5.0          A  America/New_York     airport
# 10              979             -5.0          A  America/New_York     airport
# 11              979             -5.0          A  America/New_York     airport
# 12              979             -5.0          A  America/New_York     airport
# 13              979             -5.0          A  America/New_York     airport
# 14              979             -5.0          A  America/New_York     airport
# 15              979             -5.0          A  America/New_York     airport
# 16              979             -5.0          A  America/New_York     airport
# 17              979             -5.0          A  America/New_York     airport
# 18              979             -5.0          A  America/New_York     airport
# 19              979             -5.0          A  America/New_York     airport
#
#        source_y  id_dest                                          name_dest  \
# 0   OurAirports     3682   Hartsfield Jackson Atlanta International Airport
# 1   OurAirports     3876            Charlotte Douglas International Airport
# 2   OurAirports     3670            Dallas Fort Worth International Airport
# 3   OurAirports     3830               Chicago O'Hare International Airport
# 4   OurAirports     3682   Hartsfield Jackson Atlanta International Airport
# 5   OurAirports     3682   Hartsfield Jackson Atlanta International Airport
# 6   OurAirports     3520          Ronald Reagan Washington National Airport
# 7   OurAirports     3645          Detroit Metropolitan Wayne County Airport
# 8   OurAirports     3697                                 La Guardia Airport
# 9   OurAirports     3858  Minneapolis-St Paul International/Wold-Chamber...
# 10  OurAirports     3533    Fort Lauderdale Hollywood International Airport
# 11  OurAirports     7056                           Charlotte County Airport
# 12  OurAirports     3617     St Petersburg Clearwater International Airport
# 13  OurAirports     4167              Orlando Sanford International Airport
# 14  OurAirports     3682   Hartsfield Jackson Atlanta International Airport
# 15  OurAirports     3550       George Bush Intercontinental Houston Airport
# 16  OurAirports     3830               Chicago O'Hare International Airport
# 17  OurAirports     3876            Charlotte Douglas International Airport
# 18  OurAirports     3670            Dallas Fort Worth International Airport
# 19  OurAirports     3830               Chicago O'Hare International Airport
#
#             city_dest   country_dest iata_dest icao_dest  latitude_dest  \
# 0             Atlanta  United States       ATL      KATL      33.636700
# 1           Charlotte  United States       CLT      KCLT      35.214001
# 2   Dallas-Fort Worth  United States       DFW      KDFW      32.896801
# 3             Chicago  United States       ORD      KORD      41.978600
# 4             Atlanta  United States       ATL      KATL      33.636700
# 5             Atlanta  United States       ATL      KATL      33.636700
# 6          Washington  United States       DCA      KDCA      38.852100
# 7             Detroit  United States       DTW      KDTW      42.212399
# 8            New York  United States       LGA      KLGA      40.777199
# 9         Minneapolis  United States       MSP      KMSP      44.882000
# 10    Fort Lauderdale  United States       FLL      KFLL      26.072599
# 11        Punta Gorda  United States       PGD      KPGD      26.920200
# 12     St. Petersburg  United States       PIE      KPIE      27.910200
# 13            Sanford  United States       SFB      KSFB      28.777599
# 14            Atlanta  United States       ATL      KATL      33.636700
# 15            Houston  United States       IAH      KIAH      29.984400
# 16            Chicago  United States       ORD      KORD      41.978600
# 17          Charlotte  United States       CLT      KCLT      35.214001
# 18  Dallas-Fort Worth  United States       DFW      KDFW      32.896801
# 19            Chicago  United States       ORD      KORD      41.978600
#
#     longitude_dest  altitude_dest  timezone_dest dst_dest           tz_dest  \
# 0       -84.428101           1026           -5.0        A  America/New_York
# 1       -80.943100            748           -5.0        A  America/New_York
# 2       -97.038002            607           -6.0        A   America/Chicago
# 3       -87.904800            672           -6.0        A   America/Chicago
# 4       -84.428101           1026           -5.0        A  America/New_York
# 5       -84.428101           1026           -5.0        A  America/New_York
# 6       -77.037697             15           -5.0        A  America/New_York
# 7       -83.353401            645           -5.0        A  America/New_York
# 8       -73.872597             21           -5.0        A  America/New_York
# 9       -93.221802            841           -6.0        A   America/Chicago
# 10      -80.152702              9           -5.0        A  America/New_York
# 11      -81.990501             26           -5.0        A  America/New_York
# 12      -82.687401             11           -5.0        A  America/New_York
# 13      -81.237503             55           -5.0        A  America/New_York
# 14      -84.428101           1026           -5.0        A  America/New_York
# 15      -95.341400             97           -6.0        A   America/Chicago
# 16      -87.904800            672           -6.0        A   America/Chicago
# 17      -80.943100            748           -5.0        A  America/New_York
# 18      -97.038002            607           -6.0        A   America/Chicago
# 19      -87.904800            672           -6.0        A   America/Chicago
#
#    type_dest       source
# 0    airport  OurAirports
# 1    airport  OurAirports
# 2    airport  OurAirports
# 3    airport  OurAirports
# 4    airport  OurAirports
# 5    airport  OurAirports
# 6    airport  OurAirports
# 7    airport  OurAirports
# 8    airport  OurAirports
# 9    airport  OurAirports
# 10   airport  OurAirports
# 11   airport  OurAirports
# 12   airport  OurAirports
# 13   airport  OurAirports
# 14   airport  OurAirports
# 15   airport  OurAirports
# 16   airport  OurAirports
# 17   airport  OurAirports
# 18   airport  OurAirports
# 19   airport  OurAirports

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 1       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 2       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 3       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 6       DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 7       DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 8       DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 9       DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 10      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 11      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 12      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 13      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 15      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#       equipment  id_source         name_source   city_source country_source  \
# 0           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 1       CR7 CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 2       ERD ER4       4017  Blue Grass Airport  Lexington KY  United States
# 3       ERD ER4       4017  Blue Grass Airport  Lexington KY  United States
# 6           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 7   CR7 CRJ CR9       4017  Blue Grass Airport  Lexington KY  United States
# 8           ERJ       4017  Blue Grass Airport  Lexington KY  United States
# 9           CRJ       4017  Blue Grass Airport  Lexington KY  United States
# 10          M80       4017  Blue Grass Airport  Lexington KY  United States
# 11          M80       4017  Blue Grass Airport  Lexington KY  United States
# 12          320       4017  Blue Grass Airport  Lexington KY  United States
# 13      M80 320       4017  Blue Grass Airport  Lexington KY  United States
# 15          ERJ       4017  Blue Grass Airport  Lexington KY  United States
#
#    iata_source icao_source  latitude_source  longitude_source  \
# 0          LEX        KLEX        38.036499        -84.605904
# 1          LEX        KLEX        38.036499        -84.605904
# 2          LEX        KLEX        38.036499        -84.605904
# 3          LEX        KLEX        38.036499        -84.605904
# 6          LEX        KLEX        38.036499        -84.605904
# 7          LEX        KLEX        38.036499        -84.605904
# 8          LEX        KLEX        38.036499        -84.605904
# 9          LEX        KLEX        38.036499        -84.605904
# 10         LEX        KLEX        38.036499        -84.605904
# 11         LEX        KLEX        38.036499        -84.605904
# 12         LEX        KLEX        38.036499        -84.605904
# 13         LEX        KLEX        38.036499        -84.605904
# 15         LEX        KLEX        38.036499        -84.605904
#
#     altitude_source  timezone_source dst_source         tz_source type_source  \
# 0               979             -5.0          A  America/New_York     airport
# 1               979             -5.0          A  America/New_York     airport
# 2               979             -5.0          A  America/New_York     airport
# 3               979             -5.0          A  America/New_York     airport
# 6               979             -5.0          A  America/New_York     airport
# 7               979             -5.0          A  America/New_York     airport
# 8               979             -5.0          A  America/New_York     airport
# 9               979             -5.0          A  America/New_York     airport
# 10              979             -5.0          A  America/New_York     airport
# 11              979             -5.0          A  America/New_York     airport
# 12              979             -5.0          A  America/New_York     airport
# 13              979             -5.0          A  America/New_York     airport
# 15              979             -5.0          A  America/New_York     airport
#
#     id_dest                                          name_dest  \
# 0      3682   Hartsfield Jackson Atlanta International Airport
# 1      3876            Charlotte Douglas International Airport
# 2      3670            Dallas Fort Worth International Airport
# 3      3830               Chicago O'Hare International Airport
# 6      3520          Ronald Reagan Washington National Airport
# 7      3645          Detroit Metropolitan Wayne County Airport
# 8      3697                                 La Guardia Airport
# 9      3858  Minneapolis-St Paul International/Wold-Chamber...
# 10     3533    Fort Lauderdale Hollywood International Airport
# 11     7056                           Charlotte County Airport
# 12     3617     St Petersburg Clearwater International Airport
# 13     4167              Orlando Sanford International Airport
# 15     3550       George Bush Intercontinental Houston Airport
#
#             city_dest   country_dest iata_dest icao_dest  latitude_dest  \
# 0             Atlanta  United States       ATL      KATL      33.636700
# 1           Charlotte  United States       CLT      KCLT      35.214001
# 2   Dallas-Fort Worth  United States       DFW      KDFW      32.896801
# 3             Chicago  United States       ORD      KORD      41.978600
# 6          Washington  United States       DCA      KDCA      38.852100
# 7             Detroit  United States       DTW      KDTW      42.212399
# 8            New York  United States       LGA      KLGA      40.777199
# 9         Minneapolis  United States       MSP      KMSP      44.882000
# 10    Fort Lauderdale  United States       FLL      KFLL      26.072599
# 11        Punta Gorda  United States       PGD      KPGD      26.920200
# 12     St. Petersburg  United States       PIE      KPIE      27.910200
# 13            Sanford  United States       SFB      KSFB      28.777599
# 15            Houston  United States       IAH      KIAH      29.984400
#
#     longitude_dest  altitude_dest  timezone_dest dst_dest           tz_dest  \
# 0       -84.428101           1026           -5.0        A  America/New_York
# 1       -80.943100            748           -5.0        A  America/New_York
# 2       -97.038002            607           -6.0        A   America/Chicago
# 3       -87.904800            672           -6.0        A   America/Chicago
# 6       -77.037697             15           -5.0        A  America/New_York
# 7       -83.353401            645           -5.0        A  America/New_York
# 8       -73.872597             21           -5.0        A  America/New_York
# 9       -93.221802            841           -6.0        A   America/Chicago
# 10      -80.152702              9           -5.0        A  America/New_York
# 11      -81.990501             26           -5.0        A  America/New_York
# 12      -82.687401             11           -5.0        A  America/New_York
# 13      -81.237503             55           -5.0        A  America/New_York
# 15      -95.341400             97           -6.0        A   America/Chicago
#
#    type_dest
# 0    airport
# 1    airport
# 2    airport
# 3    airport
# 6    airport
# 7    airport
# 8    airport
# 9    airport
# 10   airport
# 11   airport
# 12   airport
# 13   airport
# 15   airport

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2, 
                                popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2429d7f0d49c40b68dd2f72cf969f51f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2429d7f0d49c40b68dd2f72cf969f51f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2429d7f0d49c40b68dd2f72cf969f51f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2429d7f0d49c40b68dd2f72cf969f51f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# [(38.034, -84.5),
#  (37.864933929949096, -84.49708149511396),
#  (37.695862920583586, -84.49417629534568),
#  (37.52678697986378, -84.49128425988357),
#  (37.35770611591111, -84.48840524964173),
#  (37.18862033700805, -84.48553912723197),
#  (37.019529651598035, -84.48268575693639),
#  (36.85043406828536, -84.47984500468044),
#  (36.68133359583508, -84.4770167380065),
#  (36.51222824317288, -84.474200826048),
#  (36.343118019385024, -84.47139713950395),
#  (36.17400293371815, -84.46860555061399),
#  (36.00488299557918, -84.46582593313389),
#  (35.83575821453518, -84.46305816231151),
#  (35.66662860031317, -84.46030211486323),
#  (35.49749416279997, -84.45755766895067),
#  (35.328354912042094, -84.45482470415813),
#  (35.15921085824549, -84.45210310147009),
#  (34.990062011775386, -84.44939274324938),
#  (34.82090838315612, -84.44669351321562),
#  (34.65174998307092, -84.44400529642411),
#  (34.48258682236167, -84.44132797924507),
#  (34.3134189120287, -84.43866144934323),
#  (34.14424626323062, -84.43600559565783),
#  (33.975068887284, -84.43336030838299),
#  (33.805886795663184, -84.4307254789483),
#  (33.6367, -84.428101)]

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
print(airport_set)
print(route_set)
lex_air
# Out:
# {'LEX', 'PGD', 'PIE', 'ATL', 'LGA', 'SFB', 'IAH', 'DTW', 'DCA', 'FLL', 'ORD', 'MSP', 'CLT', 'DFW'}
# {('LEX', 'FLL'), ('LEX', 'ATL'), ('LEX', 'PGD'), ('LEX', 'SFB'), ('LEX', 'CLT'), ('LEX', 'PIE'), ('LEX', 'DTW'), ('LEX', 'LGA'), ('LEX', 'MSP'), ('LEX', 'DFW'), ('LEX', 'IAH'), ('LEX', 'ORD'), ('LEX', 'DCA')}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_e9459a7943494aa187f120899f1df4c9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_e9459a7943494aa187f120899f1df4c9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_e9459a7943494aa187f120899f1df4c9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_e9459a7943494aa187f120899f1df4c9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.

# %%
# Select the LEX routes, then join the source airports
#lex_routes = routes[(routes['source']=="LEX")]
layover = pd.merge (lex_routes, routes,left_on='dest', right_on='source',how='left' )

#merge lex routes with the list of all possible destitinations from those airports

#lex_routes = pd.merge(lex_routes, airports, left_on='source_id_y', right_on='id', how='left')

# join the destination airports
layover  =pd.merge(layover, airports, left_on='source_id_y',right_on='id',how='left')


temp_airports = airports[['iata','longitude','latitude']]
#create data frame with only 3 columns

#add the lats and longs back into the data frame (they werent merged becuase of a name change earlier)
layover = pd.merge(layover, airports, left_on='dest_y',right_on='iata',how='left',suffixes=('','_final'))
layover=layover.dropna(subset=['latitude_final','longitude_final']) #drop all garbage rows

pd.set_option('display.max_columns', None)
print(layover)
#layover.loc[layover['iata'] == 'FLL']


#this will check by airport
#g = layover.groupby(['iata']).count()
#print(g)
# Out:
#      airline_x  airline_id_x source_x  source_id_x dest_x  dest_id_x  \
# 0           9E        3976.0      LEX       4017.0    ATL     3682.0
# 1           9E        3976.0      LEX       4017.0    ATL     3682.0
# 2           9E        3976.0      LEX       4017.0    ATL     3682.0
# 3           9E        3976.0      LEX       4017.0    ATL     3682.0
# 4           9E        3976.0      LEX       4017.0    ATL     3682.0
# ...        ...           ...      ...          ...    ...        ...
# 3553        UA        5209.0      LEX       4017.0    IAH     3550.0
# 3554        UA        5209.0      LEX       4017.0    IAH     3550.0
# 3555        UA        5209.0      LEX       4017.0    IAH     3550.0
# 3556        UA        5209.0      LEX       4017.0    IAH     3550.0
# 3557        UA        5209.0      LEX       4017.0    IAH     3550.0
#
#      codeshare_x  stops_x equipment_x  id_source         name_source  \
# 0            NaN        0         CRJ       4017  Blue Grass Airport
# 1            NaN        0         CRJ       4017  Blue Grass Airport
# 2            NaN        0         CRJ       4017  Blue Grass Airport
# 3            NaN        0         CRJ       4017  Blue Grass Airport
# 4            NaN        0         CRJ       4017  Blue Grass Airport
# ...          ...      ...         ...        ...                 ...
# 3553           Y        0         ERJ       4017  Blue Grass Airport
# 3554           Y        0         ERJ       4017  Blue Grass Airport
# 3555           Y        0         ERJ       4017  Blue Grass Airport
# 3556           Y        0         ERJ       4017  Blue Grass Airport
# 3557           Y        0         ERJ       4017  Blue Grass Airport
#
#        city_source country_source iata_source icao_source  latitude_source  \
# 0     Lexington KY  United States         LEX        KLEX        38.036499
# 1     Lexington KY  United States         LEX        KLEX        38.036499
# 2     Lexington KY  United States         LEX        KLEX        38.036499
# 3     Lexington KY  United States         LEX        KLEX        38.036499
# 4     Lexington KY  United States         LEX        KLEX        38.036499
# ...            ...            ...         ...         ...              ...
# 3553  Lexington KY  United States         LEX        KLEX        38.036499
# 3554  Lexington KY  United States         LEX        KLEX        38.036499
# 3555  Lexington KY  United States         LEX        KLEX        38.036499
# 3556  Lexington KY  United States         LEX        KLEX        38.036499
# 3557  Lexington KY  United States         LEX        KLEX        38.036499
#
#       longitude_source  altitude_source  timezone_source dst_source  \
# 0           -84.605904              979             -5.0          A
# 1           -84.605904              979             -5.0          A
# 2           -84.605904              979             -5.0          A
# 3           -84.605904              979             -5.0          A
# 4           -84.605904              979             -5.0          A
# ...                ...              ...              ...        ...
# 3553        -84.605904              979             -5.0          A
# 3554        -84.605904              979             -5.0          A
# 3555        -84.605904              979             -5.0          A
# 3556        -84.605904              979             -5.0          A
# 3557        -84.605904              979             -5.0          A
#
#              tz_source type_source  id_dest  \
# 0     America/New_York     airport     3682
# 1     America/New_York     airport     3682
# 2     America/New_York     airport     3682
# 3     America/New_York     airport     3682
# 4     America/New_York     airport     3682
# ...                ...         ...      ...
# 3553  America/New_York     airport     3550
# 3554  America/New_York     airport     3550
# 3555  America/New_York     airport     3550
# 3556  America/New_York     airport     3550
# 3557  America/New_York     airport     3550
#
#                                              name_dest city_dest  \
# 0     Hartsfield Jackson Atlanta International Airport   Atlanta
# 1     Hartsfield Jackson Atlanta International Airport   Atlanta
# 2     Hartsfield Jackson Atlanta International Airport   Atlanta
# 3     Hartsfield Jackson Atlanta International Airport   Atlanta
# 4     Hartsfield Jackson Atlanta International Airport   Atlanta
# ...                                                ...       ...
# 3553      George Bush Intercontinental Houston Airport   Houston
# 3554      George Bush Intercontinental Houston Airport   Houston
# 3555      George Bush Intercontinental Houston Airport   Houston
# 3556      George Bush Intercontinental Houston Airport   Houston
# 3557      George Bush Intercontinental Houston Airport   Houston
#
#        country_dest iata_dest icao_dest  latitude_dest  longitude_dest  \
# 0     United States       ATL      KATL        33.6367      -84.428101
# 1     United States       ATL      KATL        33.6367      -84.428101
# 2     United States       ATL      KATL        33.6367      -84.428101
# 3     United States       ATL      KATL        33.6367      -84.428101
# 4     United States       ATL      KATL        33.6367      -84.428101
# ...             ...       ...       ...            ...             ...
# 3553  United States       IAH      KIAH        29.9844      -95.341400
# 3554  United States       IAH      KIAH        29.9844      -95.341400
# 3555  United States       IAH      KIAH        29.9844      -95.341400
# 3556  United States       IAH      KIAH        29.9844      -95.341400
# 3557  United States       IAH      KIAH        29.9844      -95.341400
#
#       altitude_dest  timezone_dest dst_dest           tz_dest type_dest  \
# 0              1026           -5.0        A  America/New_York   airport
# 1              1026           -5.0        A  America/New_York   airport
# 2              1026           -5.0        A  America/New_York   airport
# 3              1026           -5.0        A  America/New_York   airport
# 4              1026           -5.0        A  America/New_York   airport
# ...             ...            ...      ...               ...       ...
# 3553             97           -6.0        A   America/Chicago   airport
# 3554             97           -6.0        A   America/Chicago   airport
# 3555             97           -6.0        A   America/Chicago   airport
# 3556             97           -6.0        A   America/Chicago   airport
# 3557             97           -6.0        A   America/Chicago   airport
#
#      airline_y  airline_id_y source_y  source_id_y dest_y  dest_id_y  \
# 0           3M       20710.0      ATL       3682.0    LWB     6958.0
# 1           3M       20710.0      ATL       3682.0    MCN     3754.0
# 2           3M       20710.0      ATL       3682.0    MEI     4335.0
# 3           3M       20710.0      ATL       3682.0    MSL     5756.0
# 4           3M       20710.0      ATL       3682.0    PIB     5759.0
# ...        ...           ...      ...          ...    ...        ...
# 3553        US        5265.0      IAH       3550.0    PHX     3462.0
# 3554        US        5265.0      IAH       3550.0    SAL     1892.0
# 3555        VA        5360.0      IAH       3550.0    ATL     3682.0
# 3556        VB       10646.0      IAH       3550.0    MTY     1825.0
# 3557        VS        5347.0      IAH       3550.0    ATL     3682.0
#
#      codeshare_y  stops_y  equipment_y    id  \
# 0            NaN        0          SF3  3682
# 1            NaN        0          SF3  3682
# 2            NaN        0          SF3  3682
# 3            NaN        0          SF3  3682
# 4            NaN        0          SF3  3682
# ...          ...      ...          ...   ...
# 3553         NaN        0      319 320  3550
# 3554         NaN        0          E90  3550
# 3555           Y        0  M88 717 319  3550
# 3556         NaN        0          733  3550
# 3557           Y        0  M88 717 319  3550
#
#                                                   name     city  \
# 0     Hartsfield Jackson Atlanta International Airport  Atlanta
# 1     Hartsfield Jackson Atlanta International Airport  Atlanta
# 2     Hartsfield Jackson Atlanta International Airport  Atlanta
# 3     Hartsfield Jackson Atlanta International Airport  Atlanta
# 4     Hartsfield Jackson Atlanta International Airport  Atlanta
# ...                                                ...      ...
# 3553      George Bush Intercontinental Houston Airport  Houston
# 3554      George Bush Intercontinental Houston Airport  Houston
# 3555      George Bush Intercontinental Houston Airport  Houston
# 3556      George Bush Intercontinental Houston Airport  Houston
# 3557      George Bush Intercontinental Houston Airport  Houston
#
#             country iata  icao  latitude  longitude  altitude  timezone dst  \
# 0     United States  ATL  KATL   33.6367 -84.428101      1026      -5.0   A
# 1     United States  ATL  KATL   33.6367 -84.428101      1026      -5.0   A
# 2     United States  ATL  KATL   33.6367 -84.428101      1026      -5.0   A
# 3     United States  ATL  KATL   33.6367 -84.428101      1026      -5.0   A
# 4     United States  ATL  KATL   33.6367 -84.428101      1026      -5.0   A
# ...             ...  ...   ...       ...        ...       ...       ...  ..
# 3553  United States  IAH  KIAH   29.9844 -95.341400        97      -6.0   A
# 3554  United States  IAH  KIAH   29.9844 -95.341400        97      -6.0   A
# 3555  United States  IAH  KIAH   29.9844 -95.341400        97      -6.0   A
# 3556  United States  IAH  KIAH   29.9844 -95.341400        97      -6.0   A
# 3557  United States  IAH  KIAH   29.9844 -95.341400        97      -6.0   A
#
#                     tz     type       source  id_final  \
# 0     America/New_York  airport  OurAirports    6958.0
# 1     America/New_York  airport  OurAirports    3754.0
# 2     America/New_York  airport  OurAirports    4335.0
# 3     America/New_York  airport  OurAirports    5756.0
# 4     America/New_York  airport  OurAirports    5759.0
# ...                ...      ...          ...       ...
# 3553   America/Chicago  airport  OurAirports    3462.0
# 3554   America/Chicago  airport  OurAirports    1892.0
# 3555   America/Chicago  airport  OurAirports    3682.0
# 3556   America/Chicago  airport  OurAirports    1825.0
# 3557   America/Chicago  airport  OurAirports    3682.0
#
#                                             name_final          city_final  \
# 0                            Greenbrier Valley Airport           Lewisburg
# 1                      Middle Georgia Regional Airport               Macon
# 2                                            Key Field            Meridian
# 3                   Northwest Alabama Regional Airport       Muscle Shoals
# 4                  Hattiesburg Laurel Regional Airport  Hattiesburg/Laurel
# ...                                                ...                 ...
# 3553          Phoenix Sky Harbor International Airport             Phoenix
# 3554                 El Salvador International Airport        San Salvador
# 3555  Hartsfield Jackson Atlanta International Airport             Atlanta
# 3556    General Mariano Escobedo International Airport           Monterrey
# 3557  Hartsfield Jackson Atlanta International Airport             Atlanta
#
#       country_final iata_final icao_final  latitude_final  longitude_final  \
# 0     United States        LWB       KLWB       37.858299       -80.399498
# 1     United States        MCN       KMCN       32.692799       -83.649200
# 2     United States        MEI       KMEI       32.332600       -88.751900
# 3     United States        MSL       KMSL       34.745300       -87.610199
# 4     United States        PIB       KPIB       31.467100       -89.337097
# ...             ...        ...        ...             ...              ...
# 3553  United States        PHX       KPHX       33.434299      -112.012001
# 3554    El Salvador        SAL       MSLP       13.440900       -89.055702
# 3555  United States        ATL       KATL       33.636700       -84.428101
# 3556         Mexico        MTY       MMMY       25.778500      -100.107002
# 3557  United States        ATL       KATL       33.636700       -84.428101
#
#       altitude_final  timezone_final dst_final             tz_final  \
# 0             2302.0            -5.0         U     America/New_York
# 1              354.0            -5.0         A     America/New_York
# 2              297.0            -6.0         A      America/Chicago
# 3              551.0            -6.0         A      America/Chicago
# 4              298.0            -6.0         A      America/Chicago
# ...              ...             ...       ...                  ...
# 3553          1135.0            -7.0         N      America/Phoenix
# 3554           101.0            -6.0         U  America/El_Salvador
# 3555          1026.0            -5.0         A     America/New_York
# 3556          1278.0            -6.0         S  America/Mexico_City
# 3557          1026.0            -5.0         A     America/New_York
#
#      type_final source_final
# 0       airport  OurAirports
# 1       airport  OurAirports
# 2       airport  OurAirports
# 3       airport  OurAirports
# 4       airport  OurAirports
# ...         ...          ...
# 3553    airport  OurAirports
# 3554    airport  OurAirports
# 3555    airport  OurAirports
# 3556    airport  OurAirports
# 3557    airport  OurAirports
#
# [3553 rows x 72 columns]

# %%
#this creates a map of all flights from locations that can be flown to from lex
lex_layover = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

l_dests= []  #create blank list

# Make sure we don't add duplicates, especially for the origins
#source =dest_x or source_y, dest = dest_y
#lat/long_dest ->#lat/long final
#lat/long_source -> lat/long_dest
for name, row in layover.iterrows():
    
    if row['dest_x'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['dest_x'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_layover)
        airport_set.add(row['dest_x'])
        
    if row['dest_y'] not in airport_set:
        #print(row['dest_y'])
        popup_string = row['city_dest'] + '(' + row['dest_y'] + ')'
        marker = folium.CircleMarker([row["latitude_final"], row["longitude_final"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_layover)
        airport_set.add(row['dest_y'])
    
    # PolyLine will accept a whole list of tuples, not just two
#This chunk means all unique routes will be shows
#     if (row['dest_x'],row['dest_y']) not in route_set:            
#         popup_string = row['dest_x'] + '-' + row['dest_y']       
        
#         gc_points = getGreatCirclePoints(row["latitude_dest"], 
#                                          row["longitude_dest"], 
#                                          row["latitude_final"], 
#                                          row["longitude_final"])
        
#         line = folium.PolyLine(gc_points, weight=.5, popup=popup_string)
#         line.add_to(lex_layover)
#         route_set.add((row['dest_x'],row['dest_y']))

#this chunk means all unique destinations will be shown
    if row['dest_y'] not in l_dests:            
        popup_string = row['dest_x'] + '-' + row['dest_y']       
        
        gc_points = getGreatCirclePoints(row["latitude_dest"], 
                                         row["longitude_dest"], 
                                         row["latitude_final"], 
                                         row["longitude_final"])
        
        line = folium.PolyLine(gc_points, weight=1, popup=popup_string)
        line.add_to(lex_layover)
        route_set.add((row['dest_x'],row['dest_y']))
        l_dests.append(row['dest_y'])



        
lex_layover
#print(airport_set)
#print(route_set)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_8dab1f2afae0458080f7ab2de29e62c7%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8dab1f2afae0458080f7ab2de29e62c7%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8dab1f2afae0458080f7ab2de29e62c7%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_8dab1f2afae0458080f7ab2de29e62c7%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.034%2C%20-84.5%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Select the LEX routes, then join the source airports
layover_2 = pd.merge (layover, routes,left_on='dest_y', right_on='source',how='left' )


# join the destination airports
layover_2  =pd.merge(layover_2, airports, left_on='source_id_y',right_on='id',how='left')


temp_airports = airports[['iata','longitude','latitude']]
#create data frame with only 3 columns

#add the lats and longs back into the data frame (they werent merged becuase of a name change earlier)
layover_2 = pd.merge(layover_2, airports, left_on='dest_y',right_on='iata',how='left',suffixes=('','_final'))
layover_2=layover_2.dropna(subset=['latitude_final','longitude_final']) #drop all garbage rows

pd.set_option('display.max_columns', None)
print(layover_2)
#layover.loc[layover['iata'] == 'FLL']


#this will check by airport
#g = layover.groupby(['iata']).count()
#print(g)
# Out:
#        airline_x  airline_id_x source_x  source_id_x dest_x  dest_id_x  \
# 0             9E        3976.0      LEX       4017.0    ATL     3682.0
# 1             9E        3976.0      LEX       4017.0    ATL     3682.0
# 2             9E        3976.0      LEX       4017.0    ATL     3682.0
# 3             9E        3976.0      LEX       4017.0    ATL     3682.0
# 4             9E        3976.0      LEX       4017.0    ATL     3682.0
# ...          ...           ...      ...          ...    ...        ...
# 537982        UA        5209.0      LEX       4017.0    IAH     3550.0
# 537983        UA        5209.0      LEX       4017.0    IAH     3550.0
# 537984        UA        5209.0      LEX       4017.0    IAH     3550.0
# 537985        UA        5209.0      LEX       4017.0    IAH     3550.0
# 537986        UA        5209.0      LEX       4017.0    IAH     3550.0
#
#        codeshare_x  stops_x equipment_x  id_source         name_source  \
# 0              NaN        0         CRJ       4017  Blue Grass Airport
# 1              NaN        0         CRJ       4017  Blue Grass Airport
# 2              NaN        0         CRJ       4017  Blue Grass Airport
# 3              NaN        0         CRJ       4017  Blue Grass Airport
# 4              NaN        0         CRJ       4017  Blue Grass Airport
# ...            ...      ...         ...        ...                 ...
# 537982           Y        0         ERJ       4017  Blue Grass Airport
# 537983           Y        0         ERJ       4017  Blue Grass Airport
# 537984           Y        0         ERJ       4017  Blue Grass Airport
# 537985           Y        0         ERJ       4017  Blue Grass Airport
# 537986           Y        0         ERJ       4017  Blue Grass Airport
#
#          city_source country_source iata_source icao_source  latitude_source  \
# 0       Lexington KY  United States         LEX        KLEX        38.036499
# 1       Lexington KY  United States         LEX        KLEX        38.036499
# 2       Lexington KY  United States         LEX        KLEX        38.036499
# 3       Lexington KY  United States         LEX        KLEX        38.036499
# 4       Lexington KY  United States         LEX        KLEX        38.036499
# ...              ...            ...         ...         ...              ...
# 537982  Lexington KY  United States         LEX        KLEX        38.036499
# 537983  Lexington KY  United States         LEX        KLEX        38.036499
# 537984  Lexington KY  United States         LEX        KLEX        38.036499
# 537985  Lexington KY  United States         LEX        KLEX        38.036499
# 537986  Lexington KY  United States         LEX        KLEX        38.036499
#
#         longitude_source  altitude_source  timezone_source dst_source  \
# 0             -84.605904              979             -5.0          A
# 1             -84.605904              979             -5.0          A
# 2             -84.605904              979             -5.0          A
# 3             -84.605904              979             -5.0          A
# 4             -84.605904              979             -5.0          A
# ...                  ...              ...              ...        ...
# 537982        -84.605904              979             -5.0          A
# 537983        -84.605904              979             -5.0          A
# 537984        -84.605904              979             -5.0          A
# 537985        -84.605904              979             -5.0          A
# 537986        -84.605904              979             -5.0          A
#
#                tz_source type_source  id_dest  \
# 0       America/New_York     airport     3682
# 1       America/New_York     airport     3682
# 2       America/New_York     airport     3682
# 3       America/New_York     airport     3682
# 4       America/New_York     airport     3682
# ...                  ...         ...      ...
# 537982  America/New_York     airport     3550
# 537983  America/New_York     airport     3550
# 537984  America/New_York     airport     3550
# 537985  America/New_York     airport     3550
# 537986  America/New_York     airport     3550
#
#                                                name_dest city_dest  \
# 0       Hartsfield Jackson Atlanta International Airport   Atlanta
# 1       Hartsfield Jackson Atlanta International Airport   Atlanta
# 2       Hartsfield Jackson Atlanta International Airport   Atlanta
# 3       Hartsfield Jackson Atlanta International Airport   Atlanta
# 4       Hartsfield Jackson Atlanta International Airport   Atlanta
# ...                                                  ...       ...
# 537982      George Bush Intercontinental Houston Airport   Houston
# 537983      George Bush Intercontinental Houston Airport   Houston
# 537984      George Bush Intercontinental Houston Airport   Houston
# 537985      George Bush Intercontinental Houston Airport   Houston
# 537986      George Bush Intercontinental Houston Airport   Houston
#
#          country_dest iata_dest icao_dest  latitude_dest  longitude_dest  \
# 0       United States       ATL      KATL        33.6367      -84.428101
# 1       United States       ATL      KATL        33.6367      -84.428101
# 2       United States       ATL      KATL        33.6367      -84.428101
# 3       United States       ATL      KATL        33.6367      -84.428101
# 4       United States       ATL      KATL        33.6367      -84.428101
# ...               ...       ...       ...            ...             ...
# 537982  United States       IAH      KIAH        29.9844      -95.341400
# 537983  United States       IAH      KIAH        29.9844      -95.341400
# 537984  United States       IAH      KIAH        29.9844      -95.341400
# 537985  United States       IAH      KIAH        29.9844      -95.341400
# 537986  United States       IAH      KIAH        29.9844      -95.341400
#
#         altitude_dest  timezone_dest dst_dest           tz_dest type_dest  \
# 0                1026           -5.0        A  America/New_York   airport
# 1                1026           -5.0        A  America/New_York   airport
# 2                1026           -5.0        A  America/New_York   airport
# 3                1026           -5.0        A  America/New_York   airport
# 4                1026           -5.0        A  America/New_York   airport
# ...               ...            ...      ...               ...       ...
# 537982             97           -6.0        A   America/Chicago   airport
# 537983             97           -6.0        A   America/Chicago   airport
# 537984             97           -6.0        A   America/Chicago   airport
# 537985             97           -6.0        A   America/Chicago   airport
# 537986             97           -6.0        A   America/Chicago   airport
#
#        airline_y  airline_id_y source_y  source_id_y dest_y  dest_id_y  \
# 0             3M       20710.0      ATL       3682.0    LWB     6958.0
# 1             3M       20710.0      ATL       3682.0    LWB     6958.0
# 2             3M       20710.0      ATL       3682.0    MCN     3754.0
# 3             3M       20710.0      ATL       3682.0    MCN     3754.0
# 4             3M       20710.0      ATL       3682.0    MEI     4335.0
# ...          ...           ...      ...          ...    ...        ...
# 537982        VS        5347.0      IAH       3550.0    ATL     3682.0
# 537983        VS        5347.0      IAH       3550.0    ATL     3682.0
# 537984        VS        5347.0      IAH       3550.0    ATL     3682.0
# 537985        VS        5347.0      IAH       3550.0    ATL     3682.0
# 537986        VS        5347.0      IAH       3550.0    ATL     3682.0
#
#        codeshare_y  stops_y  equipment_y  id_x  \
# 0              NaN        0          SF3  3682
# 1              NaN        0          SF3  3682
# 2              NaN        0          SF3  3682
# 3              NaN        0          SF3  3682
# 4              NaN        0          SF3  3682
# ...            ...      ...          ...   ...
# 537982           Y        0  M88 717 319  3550
# 537983           Y        0  M88 717 319  3550
# 537984           Y        0  M88 717 319  3550
# 537985           Y        0  M88 717 319  3550
# 537986           Y        0  M88 717 319  3550
#
#                                                   name_x   city_x  \
# 0       Hartsfield Jackson Atlanta International Airport  Atlanta
# 1       Hartsfield Jackson Atlanta International Airport  Atlanta
# 2       Hartsfield Jackson Atlanta International Airport  Atlanta
# 3       Hartsfield Jackson Atlanta International Airport  Atlanta
# 4       Hartsfield Jackson Atlanta International Airport  Atlanta
# ...                                                  ...      ...
# 537982      George Bush Intercontinental Houston Airport  Houston
# 537983      George Bush Intercontinental Houston Airport  Houston
# 537984      George Bush Intercontinental Houston Airport  Houston
# 537985      George Bush Intercontinental Houston Airport  Houston
# 537986      George Bush Intercontinental Houston Airport  Houston
#
#             country_x iata_x icao_x  latitude_x  longitude_x  altitude_x  \
# 0       United States    ATL   KATL     33.6367   -84.428101        1026
# 1       United States    ATL   KATL     33.6367   -84.428101        1026
# 2       United States    ATL   KATL     33.6367   -84.428101        1026
# 3       United States    ATL   KATL     33.6367   -84.428101        1026
# 4       United States    ATL   KATL     33.6367   -84.428101        1026
# ...               ...    ...    ...         ...          ...         ...
# 537982  United States    IAH   KIAH     29.9844   -95.341400          97
# 537983  United States    IAH   KIAH     29.9844   -95.341400          97
# 537984  United States    IAH   KIAH     29.9844   -95.341400          97
# 537985  United States    IAH   KIAH     29.9844   -95.341400          97
# 537986  United States    IAH   KIAH     29.9844   -95.341400          97
#
#         timezone_x dst_x              tz_x   type_x     source_x  id_final  \
# 0             -5.0     A  America/New_York  airport  OurAirports    6958.0
# 1             -5.0     A  America/New_York  airport  OurAirports    6958.0
# 2             -5.0     A  America/New_York  airport  OurAirports    3754.0
# 3             -5.0     A  America/New_York  airport  OurAirports    3754.0
# 4             -5.0     A  America/New_York  airport  OurAirports    4335.0
# ...            ...   ...               ...      ...          ...       ...
# 537982        -6.0     A   America/Chicago  airport  OurAirports    3682.0
# 537983        -6.0     A   America/Chicago  airport  OurAirports    3682.0
# 537984        -6.0     A   America/Chicago  airport  OurAirports    3682.0
# 537985        -6.0     A   America/Chicago  airport  OurAirports    3682.0
# 537986        -6.0     A   America/Chicago  airport  OurAirports    3682.0
#
#                                               name_final city_final  \
# 0                              Greenbrier Valley Airport  Lewisburg
# 1                              Greenbrier Valley Airport  Lewisburg
# 2                        Middle Georgia Regional Airport      Macon
# 3                        Middle Georgia Regional Airport      Macon
# 4                                              Key Field   Meridian
# ...                                                  ...        ...
# 537982  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537983  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537984  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537985  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537986  Hartsfield Jackson Atlanta International Airport    Atlanta
#
#         country_final iata_final icao_final  latitude_final  longitude_final  \
# 0       United States        LWB       KLWB       37.858299       -80.399498
# 1       United States        LWB       KLWB       37.858299       -80.399498
# 2       United States        MCN       KMCN       32.692799       -83.649200
# 3       United States        MCN       KMCN       32.692799       -83.649200
# 4       United States        MEI       KMEI       32.332600       -88.751900
# ...               ...        ...        ...             ...              ...
# 537982  United States        ATL       KATL       33.636700       -84.428101
# 537983  United States        ATL       KATL       33.636700       -84.428101
# 537984  United States        ATL       KATL       33.636700       -84.428101
# 537985  United States        ATL       KATL       33.636700       -84.428101
# 537986  United States        ATL       KATL       33.636700       -84.428101
#
#         altitude_final  timezone_final dst_final          tz_final type_final  \
# 0               2302.0            -5.0         U  America/New_York    airport
# 1               2302.0            -5.0         U  America/New_York    airport
# 2                354.0            -5.0         A  America/New_York    airport
# 3                354.0            -5.0         A  America/New_York    airport
# 4                297.0            -6.0         A   America/Chicago    airport
# ...                ...             ...       ...               ...        ...
# 537982          1026.0            -5.0         A  America/New_York    airport
# 537983          1026.0            -5.0         A  America/New_York    airport
# 537984          1026.0            -5.0         A  America/New_York    airport
# 537985          1026.0            -5.0         A  America/New_York    airport
# 537986          1026.0            -5.0         A  America/New_York    airport
#
#        source_final airline  airline_id source_y  source_id dest  dest_id  \
# 0       OurAirports      3M     20710.0      LWB     6958.0  ATL   3682.0
# 1       OurAirports      UA      5209.0      LWB     6958.0  IAD   3714.0
# 2       OurAirports      3M     20710.0      MCN     3754.0  ATL   3682.0
# 3       OurAirports      3M     20710.0      MCN     3754.0  MCO   3878.0
# 4       OurAirports      3M     20710.0      MEI     4335.0  ATL   3682.0
# ...             ...     ...         ...      ...        ...  ...      ...
# 537982  OurAirports      WN      4547.0      ATL     3682.0  STL   3678.0
# 537983  OurAirports      WN      4547.0      ATL     3682.0  TPA   3646.0
# 537984  OurAirports      WS      5416.0      ATL     3682.0  JFK   3797.0
# 537985  OurAirports      WS      5416.0      ATL     3682.0  LGA   3697.0
# 537986  OurAirports      WS      5416.0      ATL     3682.0  YYZ    193.0
#
#        codeshare  stops                    equipment  id_y  \
# 0            NaN    0.0                          SF3  3682
# 1              Y    0.0                          SF3  3682
# 2            NaN    0.0                          SF3  3682
# 3            NaN    0.0                          SF3  3682
# 4            NaN    0.0                          SF3  3682
# ...          ...    ...                          ...   ...
# 537982       NaN    0.0                      73W 733  3550
# 537983       NaN    0.0                 73W  733 73C  3550
# 537984         Y    0.0                          738  3550
# 537985         Y    0.0  320 757 M88 738 739 73H 73W  3550
# 537986         Y    0.0                      CR7 CR9  3550
#
#                                                   name_y   city_y  \
# 0       Hartsfield Jackson Atlanta International Airport  Atlanta
# 1       Hartsfield Jackson Atlanta International Airport  Atlanta
# 2       Hartsfield Jackson Atlanta International Airport  Atlanta
# 3       Hartsfield Jackson Atlanta International Airport  Atlanta
# 4       Hartsfield Jackson Atlanta International Airport  Atlanta
# ...                                                  ...      ...
# 537982      George Bush Intercontinental Houston Airport  Houston
# 537983      George Bush Intercontinental Houston Airport  Houston
# 537984      George Bush Intercontinental Houston Airport  Houston
# 537985      George Bush Intercontinental Houston Airport  Houston
# 537986      George Bush Intercontinental Houston Airport  Houston
#
#             country_y iata_y icao_y  latitude_y  longitude_y  altitude_y  \
# 0       United States    ATL   KATL     33.6367   -84.428101        1026
# 1       United States    ATL   KATL     33.6367   -84.428101        1026
# 2       United States    ATL   KATL     33.6367   -84.428101        1026
# 3       United States    ATL   KATL     33.6367   -84.428101        1026
# 4       United States    ATL   KATL     33.6367   -84.428101        1026
# ...               ...    ...    ...         ...          ...         ...
# 537982  United States    IAH   KIAH     29.9844   -95.341400          97
# 537983  United States    IAH   KIAH     29.9844   -95.341400          97
# 537984  United States    IAH   KIAH     29.9844   -95.341400          97
# 537985  United States    IAH   KIAH     29.9844   -95.341400          97
# 537986  United States    IAH   KIAH     29.9844   -95.341400          97
#
#         timezone_y dst_y              tz_y   type_y       source    id  \
# 0             -5.0     A  America/New_York  airport  OurAirports  6958
# 1             -5.0     A  America/New_York  airport  OurAirports  6958
# 2             -5.0     A  America/New_York  airport  OurAirports  3754
# 3             -5.0     A  America/New_York  airport  OurAirports  3754
# 4             -5.0     A  America/New_York  airport  OurAirports  4335
# ...            ...   ...               ...      ...          ...   ...
# 537982        -6.0     A   America/Chicago  airport  OurAirports  3682
# 537983        -6.0     A   America/Chicago  airport  OurAirports  3682
# 537984        -6.0     A   America/Chicago  airport  OurAirports  3682
# 537985        -6.0     A   America/Chicago  airport  OurAirports  3682
# 537986        -6.0     A   America/Chicago  airport  OurAirports  3682
#
#                                                     name       city  \
# 0                              Greenbrier Valley Airport  Lewisburg
# 1                              Greenbrier Valley Airport  Lewisburg
# 2                        Middle Georgia Regional Airport      Macon
# 3                        Middle Georgia Regional Airport      Macon
# 4                                              Key Field   Meridian
# ...                                                  ...        ...
# 537982  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537983  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537984  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537985  Hartsfield Jackson Atlanta International Airport    Atlanta
# 537986  Hartsfield Jackson Atlanta International Airport    Atlanta
#
#               country iata  icao   latitude  longitude  altitude  timezone  \
# 0       United States  LWB  KLWB  37.858299 -80.399498      2302      -5.0
# 1       United States  LWB  KLWB  37.858299 -80.399498      2302      -5.0
# 2       United States  MCN  KMCN  32.692799 -83.649200       354      -5.0
# 3       United States  MCN  KMCN  32.692799 -83.649200       354      -5.0
# 4       United States  MEI  KMEI  32.332600 -88.751900       297      -6.0
# ...               ...  ...   ...        ...        ...       ...       ...
# 537982  United States  ATL  KATL  33.636700 -84.428101      1026      -5.0
# 537983  United States  ATL  KATL  33.636700 -84.428101      1026      -5.0
# 537984  United States  ATL  KATL  33.636700 -84.428101      1026      -5.0
# 537985  United States  ATL  KATL  33.636700 -84.428101      1026      -5.0
# 537986  United States  ATL  KATL  33.636700 -84.428101      1026      -5.0
#
#        dst                tz     type source_final
# 0        U  America/New_York  airport  OurAirports
# 1        U  America/New_York  airport  OurAirports
# 2        A  America/New_York  airport  OurAirports
# 3        A  America/New_York  airport  OurAirports
# 4        A   America/Chicago  airport  OurAirports
# ...     ..               ...      ...          ...
# 537982   A  America/New_York  airport  OurAirports
# 537983   A  America/New_York  airport  OurAirports
# 537984   A  America/New_York  airport  OurAirports
# 537985   A  America/New_York  airport  OurAirports
# 537986   A  America/New_York  airport  OurAirports
#
# [537987 rows x 109 columns]

# %%
#this creates a map of all flights from locations that can be flown to from lex
lex_layover = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

l_dests= []  #create blank list

# Make sure we don't add duplicates, especially for the origins
#source =dest_x or source_y, dest = dest_y
#lat/long_dest ->#lat/long final
#lat/long_source -> lat/long_dest
for name, row in layover.iterrows():
    
    if row['dest_x'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['dest_x'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_layover)
        airport_set.add(row['dest_x'])
        
    if row['dest_y'] not in airport_set:
        #print(row['dest_y'])
        popup_string = row['city_dest'] + '(' + row['dest_y'] + ')'
        marker = folium.CircleMarker([row["latitude_final"], row["longitude_final"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_layover)
        airport_set.add(row['dest_y'])
    
    # PolyLine will accept a whole list of tuples, not just two
#This chunk means all unique routes will be shows
#     if (row['dest_x'],row['dest_y']) not in route_set:            
#         popup_string = row['dest_x'] + '-' + row['dest_y']       
        
#         gc_points = getGreatCirclePoints(row["latitude_dest"], 
#                                          row["longitude_dest"], 
#                                          row["latitude_final"], 
#                                          row["longitude_final"])
        
#         line = folium.PolyLine(gc_points, weight=.5, popup=popup_string)
#         line.add_to(lex_layover)
#         route_set.add((row['dest_x'],row['dest_y']))

#this chunk means all unique destinations will be shown
    if row['dest_y'] not in l_dests:            
        popup_string = row['dest_x'] + '-' + row['dest_y']       
        
        gc_points = getGreatCirclePoints(row["latitude_dest"], 
                                         row["longitude_dest"], 
                                         row["latitude_final"], 
                                         row["longitude_final"])
        
        line = folium.PolyLine(gc_points, weight=1, popup=popup_string)
        line.add_to(lex_layover)
        route_set.add((row['dest_x'],row['dest_y']))
        l_dests.append(row['dest_y'])



        
lex_layover
#print(airport_set)
#print(route_set)
